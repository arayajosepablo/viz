# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/AB_Test_Results.csv")
df1["index"] = range(0, len(df1))
df1.rename(columns={"USER_ID": "user_id_1"}, inplace=True)
df1 = df1[["index", "user_id_1", "VARIANT_NAME", "REVENUE"]]
df1.head()
# Out:
#    index  user_id_1 VARIANT_NAME  REVENUE
# 0      0        737      variant      0.0
# 1      1       2423      control      0.0
# 2      2       9411      control      0.0
# 3      3       7311      control      0.0
# 4      4       6174      variant      0.0

# %%
df2 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/ab_test.csv")
df2["index"] = range(0, len(df2))
df2.head()
# Out:
#        id     time  con_treat      page  converted  index
# 0  851104  11:48.6    control  old_page          0      0
# 1  804228  01:45.2    control  old_page          0      1
# 2  661590  55:06.2  treatment  new_page          0      2
# 3  853541  28:03.1  treatment  new_page          0      3
# 4  864975  52:26.2    control  old_page          1      4

# %%
df3 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/ab_test_results_aggregated_views_clicks_8.csv")
df3["index"] = range(0, len(df3))
df3.rename(columns={"user_id": "user_id_2"}, inplace=True)
df3.head()
# Out:
#    user_id_2    group  views  clicks  index
# 0          1  control    6.0     0.0      0
# 1          2  control    4.0     1.0      1
# 2          3  control    6.0     0.0      2
# 3          4  control    1.0     1.0      3
# 4          5  control    2.0     1.0      4

# %%
df4 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/cookie_cats.csv")
df4["index"] = range(0, len(df4))
df4.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7  index
# 0     116  gate_30               3        False        False      0
# 1     337  gate_30              38         True        False      1
# 2     377  gate_40             165         True        False      2
# 3     483  gate_40               1        False        False      3
# 4     488  gate_40             179         True         True      4

# %%
df5 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/data/Final Project Results - Experiment.csv")
df5["con_treat_2"] = "treatment"

# %%
df6 = pd.read_csv("/content/drive/MyDrive/TEC/Maestría/2023/01/Visualización/Proyecto/datos/data/Final Project Results - Control.csv")
df6["con_treat_2"] = "control"

# %%
df56 = pd.concat([df5, df6])
df56["index"] = range(0, len(df56))
df56.head()
# Out:
#           Date  Pageviews  Clicks  Enrollments  Payments con_treat_2  index
# 0  Sat, Oct 11       7716     686        105.0      34.0   treatment      0
# 1  Sun, Oct 12       9288     785        116.0      91.0   treatment      1
# 2  Mon, Oct 13      10480     884        145.0      79.0   treatment      2
# 3  Tue, Oct 14       9867     827        138.0      92.0   treatment      3
# 4  Wed, Oct 15       9793     832        140.0      94.0   treatment      4

# %%
all = pd.merge(df1, df2, on="index", how="outer")
all = pd.merge(all, df3, on="index", how="outer")
all = pd.merge(all, df4, on="index", how="outer")
all = pd.merge(all, df56, on="index", how="outer")
all.head()
# Out:
#    index  user_id_1 VARIANT_NAME  REVENUE      id     time  con_treat  \
# 0      0      737.0      variant      0.0  851104  11:48.6    control
# 1      1     2423.0      control      0.0  804228  01:45.2    control
# 2      2     9411.0      control      0.0  661590  55:06.2  treatment
# 3      3     7311.0      control      0.0  853541  28:03.1  treatment
# 4      4     6174.0      variant      0.0  864975  52:26.2    control
#
#        page  converted  user_id_2  ...  version  sum_gamerounds  retention_1  \
# 0  old_page          0        1.0  ...  gate_30             3.0        False
# 1  old_page          0        2.0  ...  gate_30            38.0         True
# 2  new_page          0        3.0  ...  gate_40           165.0         True
# 3  new_page          0        4.0  ...  gate_40             1.0        False
# 4  old_page          1        5.0  ...  gate_40           179.0         True
#
#    retention_7         Date  Pageviews Clicks Enrollments Payments  \
# ...

# %%
from google.colab import files

all.to_csv('all.csv', index=False) 
files.download('all.csv')
